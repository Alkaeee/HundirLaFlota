# %%
import src.functions as ft

# %%
p1, t1 = ft.create_player()
print(t1.table)
# Out:
# [[' ' ' ' ' ' 'O' 'O' ' ' 'O' 'O' 'O' 'O']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' 'O' 'O' 'O' ' ' 'O' ' ' ' ' 'O' ' ']
#  [' ' ' ' ' ' ' ' ' ' 'O' ' ' ' ' ' ' ' ']
#  [' ' ' ' 'O' 'O' ' ' 'O' ' ' ' ' 'O' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  ['O' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  ['O' ' ' ' ' ' ' ' ' 'O' ' ' 'O' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']]

# %%
ft.create_demo()
# Out:
# ____________________________________________
# Machine table:
# [[' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' 'O' 'O' ' ' ' ']
#  [' ' ' ' ' ' 'O' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']]
# Your table:
#  [[' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' 'O' ' ' ' ' 'O' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' 'O' ' ' ' ' ' ' ' ' ' ']]
# Your shots:
# ...

# %%
ft.play_game()
# Out:
# ____________________________________________
# Your table:
#  [[' ' ' ' ' ' ' ' ' ' 'O' 'O' 'O' ' ' ' ']
#  [' ' ' ' 'O' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' 'O' ' ' ' ' ' ' ' ']
#  ['O' 'O' ' ' ' ' ' ' ' ' ' ' 'O' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' 'O' ' ' ' ' ' ' ' ']
#  [' ' 'O' 'O' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' 'O' ' ' 'O' ' ']
#  [' ' 'O' 'O' 'O' 'O' ' ' 'O' ' ' 'O' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' 'O' ' ']]
# Your shots:
#  []
# Record PLAYER:  [(0, 0)]
# Given
# Your table:
#  [[' ' ' ' ' ' ' ' ' ' 'O' 'O' 'O' ' ' ' ']
#  [' ' ' ' 'O' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' 'O' ' ' ' ' ' ' ' ']
#  ['O' 'O' ' ' ' ' ' ' ' ' ' ' 'O' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' 'O' ' ' ' ' ' ' ' ']
#  [' ' 'O' 'O' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' 'O' ' ' 'O' ' ']
#  [' ' 'O' 'O' 'O' 'O' ' ' 'O' ' ' 'O' ' ']
# ...
